# %%
import copernicusmarine

# %%
# Info sur les options disponibles
# ?copernicusmarine.get

# %%
#  l'ID se trouve sur les pages produits du copernicus marine datastore :
# https://data.marine.copernicus.eu/products?dateRange=begin%7E2025-01-01--end%7E2025-05-31&facets=vertLevels%7Etrue--areas%7EMediterranean+Sea
copernicusmarine.get(dataset_id='cmems_mod_med_phy-cur_anfc_4.2km_P1D-m')

# Y pour télécharger les documents listées
# n pour ne ne pas les télécharger

# %%
copernicusmarine.get(dataset_id='cmems_mod_med_phy-cur_anfc_4.2km_P1D-m',
                    force_download=True,
                     # 2 aout 2024
                    filter='*20240802*'
                    )
