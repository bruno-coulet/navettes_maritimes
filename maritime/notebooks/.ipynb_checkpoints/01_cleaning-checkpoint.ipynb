# %%
import pandas as pd
from cleaning_utils import load_raw_data, clean_raw_data, reorganize_columns

source = '../data/consolidation_maritime.xlsx'

# Chargement
df = load_raw_data(source)

# Nettoyage
df = clean_raw_data(df)

# Réorganisation
df = reorganize_columns(df)

# Export
df.to_csv("../data/maritime_clean.csv", index=True)
# Out:
# C:\Users\bcoulet\Documents\projets\maritime\notebooks\cleaning_utils.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Meteo1'] = df['Météo'].str.extract(r'^(.*?)\b(Vent|Mer)\b', expand=False)[0]
# C:\Users\bcoulet\Documents\projets\maritime\notebooks\cleaning_utils.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MeteoVent'] = df['Météo'].str.extract(r'(Vent.*?)(?=Mer\b)', expand=False)
# C:\Users\bcoulet\Documents\projets\maritime\notebooks\cleaning_utils.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['MeteoHoule'] = df['Météo'].str.extract(r'(Mer\s*:?.*)$', expand=False)
# C:\Users\bcoulet\Documents\projets\maritime\notebooks\cleaning_utils.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Temperature'] = df['Meteo1'].str.extract(r'(?P<Temperature>\d+)°')
# C:\Users\bcoulet\Documents\projets\maritime\notebooks\cleaning_utils.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Ciel'] = df['Meteo1'].str.extract(r'\d+°\s*(.*)')
